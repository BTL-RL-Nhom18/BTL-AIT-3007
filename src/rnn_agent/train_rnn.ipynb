# %%
# %cd /kaggle/working
# %rm -rf BTL-AIT-3007
# !git clone -b manh https://github.com/BTL-RL-Nhom18/BTL-AIT-3007.git
# %cd BTL-AIT-3007
# Out:
# /kaggle/working
# Cloning into 'BTL-AIT-3007'...
# remote: Enumerating objects: 776, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 776 (delta 25), reused 32 (delta 24), pack-reused 719 (from 1)
# Receiving objects: 100% (776/776), 21.74 MiB | 47.15 MiB/s, done.
# Resolving deltas: 100% (495/495), done.
# /kaggle/working/BTL-AIT-3007

# %%
# %pip install -r requirements.txt -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python src/rnn_agent/train_rnn.py --batch_size 4 \
                        --max_steps 300 \
                        --target_update_interval 10 \
                        --seed 40 \
                        --save_interval 8 \
                        --max_episodes 120 \
                        --model_path model/rnn \
                        --epsilon_decay 0.95 \
                        --learning_rate 0.00001
# Out:
# 40
# Start episode 0 ----------------------
# Episode 0: Reward = -11.34, Loss = N/A
# Start episode 1 ----------------------
# Episode 1: Reward = -10.81, Loss = N/A
# Start episode 2 ----------------------
# Episode 2: Reward = -10.95, Loss = N/A
# Start episode 3 ----------------------
# Epoch 100/1, Loss: 0.008749620988965034
# Episode 3: Reward = -10.95, Loss = 0.008749620988965034
# Start episode 4 ----------------------
# Epoch 100/1, Loss: 0.008093658834695816
# Episode 4: Reward = -11.44, Loss = 0.008093658834695816
# Start episode 5 ----------------------
# Epoch 100/1, Loss: 0.0069939251989126205
# Episode 5: Reward = -10.76, Loss = 0.0069939251989126205
# Start episode 6 ----------------------
# Epoch 100/1, Loss: 0.005787407048046589
# Episode 6: Reward = -10.09, Loss = 0.005787407048046589
# Start episode 7 ----------------------
# Epoch 100/1, Loss: 0.004011145327240229
# Episode 7: Reward = -9.30, Loss = 0.004011145327240229
# Start episode 8 ----------------------
# ...
