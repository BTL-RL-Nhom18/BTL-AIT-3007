# %%
# %cd /kaggle/working
# %rm -rf BTL-AIT-3007
# !git clone -b manh https://github.com/BTL-RL-Nhom19/BTL-AIT-3007.git
# %cd BTL-AIT-3007
# Out:
# /kaggle/working
# Cloning into 'BTL-AIT-3007'...
# remote: Enumerating objects: 887, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 887 (delta 84), reused 102 (delta 47), pack-reused 719 (from 1)
# Receiving objects: 100% (887/887), 30.79 MiB | 40.17 MiB/s, done.
# Resolving deltas: 100% (554/554), done.
# /kaggle/working/BTL-AIT-3007

# %%
# %pip install -r requirements.txt -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 522.8/522.8 kB 25.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cd src/rnn_agent
# !python eval_rnn_new.py
# Out:
# /kaggle/working/BTL-AIT-3007/src/rnn_agent
# ...
# Eval with random policy
# /usr/local/lib/python3.10/dist-packages/pettingzoo/utils/wrappers/base.py:72: UserWarning: The `action_spaces` dictionary is deprecated. Use the `action_space` function instead.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 30/30 [17:51<00:00, 35.73s/it]
# {'winrate_red': 0.0, 'winrate_blue': 1.0, 'average_rewards_red': -7.341092863620292, 'average_rewards_blue': 0.9128271491220796}
# ...
# Eval with trained policy
# /usr/local/lib/python3.10/dist-packages/pettingzoo/utils/wrappers/base.py:72: UserWarning: The `action_spaces` dictionary is deprecated. Use the `action_space` function instead.
#   warnings.warn(
# 100%|███████████████████████████████████████████| 30/30 [09:49<00:00, 19.64s/it]
# {'winrate_red': 1.0, 'winrate_blue': 0.0, 'average_rewards_red': 1.8097386322447975, 'average_rewards_blue': 0.4159423625203992}
# ...
# Eval with final trained policy
# ...
