# %%
# %cd /kaggle/working
# %rm -rf BTL-AIT-3007
# !git clone -b manh https://github.com/BTL-RL-Nhom18/BTL-AIT-3007.git
# %cd BTL-AIT-3007
# Out:
# /kaggle/working
# Cloning into 'BTL-AIT-3007'...
# remote: Enumerating objects: 776, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 776 (delta 25), reused 32 (delta 24), pack-reused 719 (from 1)
# Receiving objects: 100% (776/776), 21.74 MiB | 23.38 MiB/s, done.
# Resolving deltas: 100% (495/495), done.
# /kaggle/working/BTL-AIT-3007

# %%
# %pip install -r requirements.txt -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python src/qmix/train_qmix.py --batch_size 4 \
                        --max_steps 300 \
                        --target_update_interval 10 \
                        --seed 40 \
                        --save_interval 8 \
                        --max_episodes 120 \
                        --model_path model/qmix \
                        --epsilon_decay 0.95 \
                        --learning_rate 0.00001
# Out:
# cuda
# 40
# Start episode 0 ----------------------
# Episode 0: Reward = -11.55, TR = N/A, Loss = N/A
# Start episode 1 ----------------------
# Episode 1: Reward = -11.07, TR = N/A, Loss = N/A
# Start episode 2 ----------------------
# Episode 2: Reward = -11.41, TR = N/A, Loss = N/A
# Start episode 3 ----------------------
# Epoch 100/1, Loss: 3.583862781524658
# Epoch 100/2, Loss: 1.053207516670227
# Epoch 100/3, Loss: 0.23698000609874725
# Epoch 100/4, Loss: 0.05904160439968109
# Episode 3: Reward = -11.68, TR = -11.68, Loss = 0.05904160439968109
# Start episode 4 ----------------------
# Epoch 100/1, Loss: 0.11985697597265244
# Epoch 100/2, Loss: 0.0196232907474041
# Episode 4: Reward = -11.66, TR = -11.41, Loss = 0.0196232907474041
# Start episode 5 ----------------------
# Epoch 100/1, Loss: 0.05547695234417915
# Episode 5: Reward = -13.30, TR = -11.41, Loss = 0.05547695234417915
# Start episode 6 ----------------------
# Epoch 100/1, Loss: 0.04592367261648178
# Episode 6: Reward = -14.14, TR = -13.3, Loss = 0.04592367261648178
# Start episode 7 ----------------------
# Epoch 100/1, Loss: 0.04177716001868248
# Episode 7: Reward = -13.52, TR = -11.66, Loss = 0.04177716001868248
# Start episode 8 ----------------------
# Epoch 100/1, Loss: 0.039107996970415115
# Episode 8: Reward = -15.30, TR = -14.14, Loss = 0.039107996970415115
# Start episode 9 ----------------------
# Epoch 100/1, Loss: 0.028514385223388672
# Episode 9: Reward = -15.71, TR = -13.52, Loss = 0.028514385223388672
# Start episode 10 ----------------------
# Epoch 100/1, Loss: 0.039725832641124725
# Episode 10: Reward = -16.59, TR = -15.71, Loss = 0.039725832641124725
# Start episode 11 ----------------------
# Epoch 100/1, Loss: 0.036394696682691574
# Episode 11: Reward = -16.05, TR = -15.71, Loss = 0.036394696682691574
# Start episode 12 ----------------------
# Epoch 100/1, Loss: 0.0321013405919075
# Episode 12: Reward = -17.33, TR = -16.05, Loss = 0.0321013405919075
# Start episode 13 ----------------------
# Epoch 100/1, Loss: 0.24649958312511444
# Epoch 100/2, Loss: 0.027770306915044785
# Episode 13: Reward = -17.76, TR = -16.05, Loss = 0.027770306915044785
# Start episode 14 ----------------------
# Epoch 100/1, Loss: 0.06669226288795471
# Episode 14: Reward = -17.80, TR = -17.76, Loss = 0.06669226288795471
# Start episode 15 ----------------------
# Epoch 100/1, Loss: 0.051308970898389816
# Episode 15: Reward = -19.79, TR = -19.79, Loss = 0.051308970898389816
# Start episode 16 ----------------------
# Epoch 100/1, Loss: 0.05161542072892189
# Episode 16: Reward = -19.51, TR = -17.76, Loss = 0.05161542072892189
# Start episode 17 ----------------------
# Epoch 100/1, Loss: 0.05540760979056358
# Episode 17: Reward = -20.53, TR = -19.51, Loss = 0.05540760979056358
# Start episode 18 ----------------------
# Epoch 100/1, Loss: 0.04043416306376457
# Episode 18: Reward = -20.93, TR = -20.93, Loss = 0.04043416306376457
# Start episode 19 ----------------------
# Epoch 100/1, Loss: 0.02384173683822155
# Episode 19: Reward = -20.13, TR = -19.51, Loss = 0.02384173683822155
# Start episode 20 ----------------------
# Epoch 100/1, Loss: 0.027075834572315216
# Episode 20: Reward = -20.67, TR = -20.13, Loss = 0.027075834572315216
# Start episode 21 ----------------------
# Epoch 100/1, Loss: 0.02790040709078312
# Episode 21: Reward = -22.03, TR = -20.67, Loss = 0.02790040709078312
# Start episode 22 ----------------------
# Epoch 100/1, Loss: 0.022985223680734634
# Episode 22: Reward = -21.75, TR = -22.03, Loss = 0.022985223680734634
# Start episode 23 ----------------------
# Epoch 100/1, Loss: 0.16709209978580475
# Epoch 100/2, Loss: 0.010900602675974369
# Episode 23: Reward = -22.54, TR = -22.03, Loss = 0.010900602675974369
# Start episode 24 ----------------------
# Epoch 100/1, Loss: 0.023137621581554413
# Episode 24: Reward = -22.67, TR = -22.03, Loss = 0.023137621581554413
# Start episode 25 ----------------------
# Epoch 100/1, Loss: 0.037020642310380936
# Episode 25: Reward = -22.75, TR = -22.67, Loss = 0.037020642310380936
# Start episode 26 ----------------------
# Epoch 100/1, Loss: 0.024017373099923134
# Episode 26: Reward = -23.22, TR = -22.75, Loss = 0.024017373099923134
# Start episode 27 ----------------------
# Epoch 100/1, Loss: 0.024850020185112953
# Episode 27: Reward = -23.86, TR = -23.86, Loss = 0.024850020185112953
# Start episode 28 ----------------------
# Epoch 100/1, Loss: 0.022848285734653473
# Episode 28: Reward = -24.61, TR = -24.61, Loss = 0.022848285734653473
# Start episode 29 ----------------------
# Epoch 100/1, Loss: 0.02181546948850155
# Episode 29: Reward = -24.57, TR = -24.57, Loss = 0.02181546948850155
# Start episode 30 ----------------------
# Epoch 100/1, Loss: 0.021448155865073204
# Episode 30: Reward = -25.49, TR = -24.61, Loss = 0.021448155865073204
# Start episode 31 ----------------------
# Epoch 100/1, Loss: 0.03208461031317711
# Episode 31: Reward = -24.97, TR = -24.97, Loss = 0.03208461031317711
# Start episode 32 ----------------------
# Epoch 100/1, Loss: 0.014649057760834694
# Episode 32: Reward = -25.39, TR = -24.97, Loss = 0.014649057760834694
# Start episode 33 ----------------------
# Epoch 100/1, Loss: 0.11677399277687073
# Epoch 100/2, Loss: 0.007923413068056107
# Episode 33: Reward = -25.27, TR = -25.39, Loss = 0.007923413068056107
# Start episode 34 ----------------------
# Epoch 100/1, Loss: 0.025866737589240074
# Episode 34: Reward = -25.77, TR = -25.39, Loss = 0.025866737589240074
# Start episode 35 ----------------------
# Epoch 100/1, Loss: 0.027294494211673737
# Episode 35: Reward = -25.10, TR = -25.39, Loss = 0.027294494211673737
# Start episode 36 ----------------------
# Epoch 100/1, Loss: 0.02361879125237465
# Episode 36: Reward = -25.72, TR = -25.27, Loss = 0.02361879125237465
# Start episode 37 ----------------------
# Epoch 100/1, Loss: 0.03956899791955948
# Episode 37: Reward = -26.18, TR = -25.77, Loss = 0.03956899791955948
# Start episode 38 ----------------------
# Epoch 100/1, Loss: 0.019217487424612045
# Episode 38: Reward = -27.07, TR = -25.1, Loss = 0.019217487424612045
# Start episode 39 ----------------------
# Epoch 100/1, Loss: 0.03996609151363373
# Episode 39: Reward = -26.51, TR = -25.72, Loss = 0.03996609151363373
# Start episode 40 ----------------------
# Epoch 100/1, Loss: 0.01575370505452156
# Episode 40: Reward = -26.38, TR = -26.51, Loss = 0.01575370505452156
# Start episode 41 ----------------------
# Epoch 100/1, Loss: 0.013277899473905563
# Episode 41: Reward = -26.73, TR = -26.73, Loss = 0.013277899473905563
# Start episode 42 ----------------------
# Epoch 100/1, Loss: 0.02051190659403801
# Episode 42: Reward = -25.91, TR = -26.51, Loss = 0.02051190659403801
# Start episode 43 ----------------------
# Epoch 100/1, Loss: 0.11803042143583298
# Epoch 100/2, Loss: 0.011750545352697372
# Episode 43: Reward = -25.92, TR = -26.73, Loss = 0.011750545352697372
# Start episode 44 ----------------------
# Epoch 100/1, Loss: 0.038757726550102234
# Episode 44: Reward = -27.00, TR = -25.92, Loss = 0.038757726550102234
# Start episode 45 ----------------------
# Epoch 100/1, Loss: 0.03764995187520981
# Episode 45: Reward = -26.96, TR = -27.0, Loss = 0.03764995187520981
# Start episode 46 ----------------------
# Epoch 100/1, Loss: 0.023959143087267876
# Episode 46: Reward = -25.90, TR = -27.0, Loss = 0.023959143087267876
# Start episode 47 ----------------------
# Epoch 100/1, Loss: 0.04151446744799614
# Episode 47: Reward = -27.62, TR = -25.9, Loss = 0.04151446744799614
# Start episode 48 ----------------------
# Epoch 100/1, Loss: 0.035976190119981766
# Episode 48: Reward = -27.90, TR = -26.96, Loss = 0.035976190119981766
# Start episode 49 ----------------------
# Epoch 100/1, Loss: 0.051322225481271744
# Episode 49: Reward = -26.87, TR = -27.9, Loss = 0.051322225481271744
# Start episode 50 ----------------------
# Epoch 100/1, Loss: 0.04303634911775589
# Episode 50: Reward = -26.98, TR = -27.9, Loss = 0.04303634911775589
# Start episode 51 ----------------------
# Epoch 100/1, Loss: 0.04996358975768089
# Episode 51: Reward = -28.41, TR = -26.98, Loss = 0.04996358975768089
# Start episode 52 ----------------------
# Epoch 100/1, Loss: 0.06107700988650322
# Episode 52: Reward = -27.63, TR = -26.98, Loss = 0.06107700988650322
# Start episode 53 ----------------------
# Epoch 100/1, Loss: 0.15376852452754974
# Epoch 100/2, Loss: 0.01480928622186184
# Episode 53: Reward = -26.69, TR = -26.69, Loss = 0.01480928622186184
# Start episode 54 ----------------------
# Epoch 100/1, Loss: 0.050606247037649155
# Episode 54: Reward = -27.48, TR = -26.69, Loss = 0.050606247037649155
# Start episode 55 ----------------------
# Epoch 100/1, Loss: 0.0369943231344223
# Episode 55: Reward = -28.00, TR = -26.69, Loss = 0.0369943231344223
# Start episode 56 ----------------------
# Epoch 100/1, Loss: 0.029286915436387062
# Episode 56: Reward = -28.70, TR = -27.48, Loss = 0.029286915436387062
# Start episode 57 ----------------------
# Epoch 100/1, Loss: 0.026217766106128693
# Episode 57: Reward = -28.49, TR = -28.49, Loss = 0.026217766106128693
# Start episode 58 ----------------------
# Epoch 100/1, Loss: 0.030837247148156166
# Episode 58: Reward = -28.54, TR = -28.0, Loss = 0.030837247148156166
# Start episode 59 ----------------------
# Epoch 100/1, Loss: 0.037215787917375565
# Episode 59: Reward = -27.82, TR = -28.49, Loss = 0.037215787917375565
# Start episode 60 ----------------------
# Epoch 100/1, Loss: 0.04310330003499985
# Episode 60: Reward = -27.88, TR = -27.88, Loss = 0.04310330003499985
# Start episode 61 ----------------------
# Epoch 100/1, Loss: 0.04296423867344856
# Episode 61: Reward = -28.35, TR = -27.88, Loss = 0.04296423867344856
# Start episode 62 ----------------------
# Epoch 100/1, Loss: 0.03713754191994667
# Episode 62: Reward = -28.66, TR = -28.35, Loss = 0.03713754191994667
# Start episode 63 ----------------------
# Epoch 100/1, Loss: 0.16612790524959564
# Epoch 100/2, Loss: 0.012310241349041462
# Episode 63: Reward = -28.04, TR = -28.04, Loss = 0.012310241349041462
# Start episode 64 ----------------------
# Epoch 100/1, Loss: 0.035446684807538986
# Episode 64: Reward = -29.27, TR = -28.66, Loss = 0.035446684807538986
# Start episode 65 ----------------------
# Epoch 100/1, Loss: 0.062376514077186584
# Episode 65: Reward = -28.77, TR = -29.27, Loss = 0.062376514077186584
# Start episode 66 ----------------------
# Epoch 100/1, Loss: 0.09994810074567795
# Episode 66: Reward = -28.71, TR = -28.04, Loss = 0.09994810074567795
# Start episode 67 ----------------------
# Epoch 100/1, Loss: 0.09673384577035904
# Episode 67: Reward = -28.89, TR = -28.71, Loss = 0.09673384577035904
# Start episode 68 ----------------------
# Epoch 100/1, Loss: 0.08510040491819382
# Episode 68: Reward = -28.30, TR = -28.3, Loss = 0.08510040491819382
# Start episode 69 ----------------------
# Epoch 100/1, Loss: 0.09626305103302002
# Episode 69: Reward = -28.53, TR = -28.71, Loss = 0.09626305103302002
# Start episode 70 ----------------------
# Epoch 100/1, Loss: 0.07624132931232452
# Episode 70: Reward = -28.11, TR = -28.53, Loss = 0.07624132931232452
# Start episode 71 ----------------------
# Epoch 100/1, Loss: 0.0488940104842186
# Episode 71: Reward = -28.08, TR = -28.3, Loss = 0.0488940104842186
# Start episode 72 ----------------------
# Epoch 100/1, Loss: 0.04882792383432388
# Episode 72: Reward = -27.54, TR = -28.08, Loss = 0.04882792383432388
# Start episode 73 ----------------------
# Epoch 100/1, Loss: 0.16829289495944977
# Epoch 100/2, Loss: 0.03884416073560715
# Episode 73: Reward = -28.84, TR = -28.08, Loss = 0.03884416073560715
# Start episode 74 ----------------------
# Epoch 100/1, Loss: 0.05500134453177452
# Episode 74: Reward = -29.14, TR = -29.14, Loss = 0.05500134453177452
# Start episode 75 ----------------------
# Epoch 100/1, Loss: 0.050011444836854935
# Episode 75: Reward = -28.96, TR = -27.54, Loss = 0.050011444836854935
# Start episode 76 ----------------------
# Epoch 100/1, Loss: 0.036208197474479675
# Episode 76: Reward = -28.98, TR = -28.98, Loss = 0.036208197474479675
# Start episode 77 ----------------------
# Epoch 100/1, Loss: 0.039592545479536057
# Episode 77: Reward = -28.66, TR = -28.96, Loss = 0.039592545479536057
# Start episode 78 ----------------------
# Epoch 100/1, Loss: 0.05504327267408371
# Episode 78: Reward = -28.48, TR = -28.98, Loss = 0.05504327267408371
# Start episode 79 ----------------------
# Epoch 100/1, Loss: 0.048258669674396515
# Episode 79: Reward = -27.92, TR = -28.66, Loss = 0.048258669674396515
# Start episode 80 ----------------------
# Epoch 100/1, Loss: 0.062266528606414795
# Episode 80: Reward = -28.68, TR = -28.48, Loss = 0.062266528606414795
# Start episode 81 ----------------------
# Epoch 100/1, Loss: 0.029964597895741463
# Episode 81: Reward = -28.48, TR = -28.68, Loss = 0.029964597895741463
# Start episode 82 ----------------------
# Epoch 100/1, Loss: 0.047184016555547714
# Episode 82: Reward = -28.29, TR = -28.29, Loss = 0.047184016555547714
# Start episode 83 ----------------------
# Epoch 100/1, Loss: 0.2037706822156906
# Epoch 100/2, Loss: 0.017775360494852066
# Episode 83: Reward = -28.56, TR = -28.68, Loss = 0.017775360494852066
# Start episode 84 ----------------------
# Epoch 100/1, Loss: 0.04931899905204773
# Episode 84: Reward = -27.70, TR = -28.56, Loss = 0.04931899905204773
# Start episode 85 ----------------------
# Epoch 100/1, Loss: 0.06116689369082451
# Episode 85: Reward = -28.45, TR = -28.45, Loss = 0.06116689369082451
# Start episode 86 ----------------------
# Epoch 100/1, Loss: 0.04040523245930672
# Episode 86: Reward = -28.93, TR = -28.56, Loss = 0.04040523245930672
# Start episode 87 ----------------------
# Epoch 100/1, Loss: 0.0352325476706028
# Episode 87: Reward = -28.50, TR = -28.5, Loss = 0.0352325476706028
# Start episode 88 ----------------------
# Epoch 100/1, Loss: 0.05518617853522301
# Episode 88: Reward = -27.99, TR = -28.93, Loss = 0.05518617853522301
# Start episode 89 ----------------------
# Epoch 100/1, Loss: 0.05452926829457283
# Episode 89: Reward = -28.60, TR = -28.6, Loss = 0.05452926829457283
# Start episode 90 ----------------------
# Epoch 100/1, Loss: 0.05826632305979729
# Episode 90: Reward = -28.63, TR = -27.99, Loss = 0.05826632305979729
# Start episode 91 ----------------------
# Epoch 100/1, Loss: 0.06653757393360138
# Episode 91: Reward = -28.84, TR = -28.63, Loss = 0.06653757393360138
# Start episode 92 ----------------------
# Epoch 100/1, Loss: 0.048243749886751175
# Episode 92: Reward = -28.16, TR = -28.6, Loss = 0.048243749886751175
# Start episode 93 ----------------------
# Epoch 100/1, Loss: 0.20174112915992737
# Epoch 100/2, Loss: 0.017426302656531334
# Episode 93: Reward = -28.66, TR = -28.63, Loss = 0.017426302656531334
# Start episode 94 ----------------------
# Epoch 100/1, Loss: 0.030608877539634705
# Episode 94: Reward = -28.85, TR = -28.16, Loss = 0.030608877539634705
# Start episode 95 ----------------------
# Epoch 100/1, Loss: 0.03506547585129738
# Episode 95: Reward = -28.21, TR = -28.21, Loss = 0.03506547585129738
# Start episode 96 ----------------------
# Epoch 100/1, Loss: 0.04387085512280464
# Episode 96: Reward = -28.47, TR = -28.47, Loss = 0.04387085512280464
# Start episode 97 ----------------------
# Epoch 100/1, Loss: 0.037778813391923904
# Episode 97: Reward = -28.82, TR = -28.21, Loss = 0.037778813391923904
# Start episode 98 ----------------------
# Epoch 100/1, Loss: 0.03708081692457199
# Episode 98: Reward = -28.64, TR = -28.21, Loss = 0.03708081692457199
# Start episode 99 ----------------------
# Epoch 100/1, Loss: 0.028926804661750793
# Episode 99: Reward = -28.86, TR = -28.86, Loss = 0.028926804661750793
# Start episode 100 ----------------------
# Epoch 100/1, Loss: 0.03534797206521034
# Episode 100: Reward = -28.55, TR = -28.55, Loss = 0.03534797206521034
# Start episode 101 ----------------------
# Epoch 100/1, Loss: 0.02794254943728447
# Episode 101: Reward = -28.18, TR = -28.64, Loss = 0.02794254943728447
# Start episode 102 ----------------------
# Epoch 100/1, Loss: 0.03705696761608124
# Episode 102: Reward = -28.64, TR = -28.55, Loss = 0.03705696761608124
# Start episode 103 ----------------------
# Epoch 100/1, Loss: 0.2726231515407562
# Epoch 100/2, Loss: 0.025636697188019753
# Episode 103: Reward = -28.54, TR = -28.55, Loss = 0.025636697188019753
# Start episode 104 ----------------------
# Epoch 100/1, Loss: 0.05897725746035576
# Episode 104: Reward = -28.52, TR = -28.54, Loss = 0.05897725746035576
# Start episode 105 ----------------------
# Epoch 100/1, Loss: 0.07106012850999832
# Episode 105: Reward = -27.99, TR = -28.64, Loss = 0.07106012850999832
# Start episode 106 ----------------------
# Epoch 100/1, Loss: 0.05959532409906387
# Episode 106: Reward = -28.32, TR = -28.32, Loss = 0.05959532409906387
# Start episode 107 ----------------------
# Epoch 100/1, Loss: 0.05362929031252861
# Episode 107: Reward = -28.24, TR = -27.99, Loss = 0.05362929031252861
# Start episode 108 ----------------------
# Epoch 100/1, Loss: 0.048648983240127563
# Episode 108: Reward = -28.11, TR = -27.99, Loss = 0.048648983240127563
# Start episode 109 ----------------------
# Epoch 100/1, Loss: 0.0583171471953392
# Episode 109: Reward = -28.22, TR = -28.22, Loss = 0.0583171471953392
# Start episode 110 ----------------------
# Epoch 100/1, Loss: 0.07227632403373718
# Episode 110: Reward = -28.33, TR = -28.24, Loss = 0.07227632403373718
# Start episode 111 ----------------------
# Epoch 100/1, Loss: 0.07735960930585861
# Episode 111: Reward = -28.27, TR = -28.27, Loss = 0.07735960930585861
# Start episode 112 ----------------------
# Epoch 100/1, Loss: 0.05384308099746704
# Episode 112: Reward = -28.32, TR = -28.22, Loss = 0.05384308099746704
# Start episode 113 ----------------------
# Epoch 100/1, Loss: 0.2418486624956131
# Epoch 100/2, Loss: 0.032122571021318436
# Episode 113: Reward = -28.44, TR = -28.44, Loss = 0.032122571021318436
# Start episode 114 ----------------------
# Epoch 100/1, Loss: 0.0674360916018486
# Episode 114: Reward = -28.58, TR = -28.44, Loss = 0.0674360916018486
# Start episode 115 ----------------------
# Epoch 100/1, Loss: 0.04383176937699318
# Episode 115: Reward = -27.63, TR = -27.63, Loss = 0.04383176937699318
# Start episode 116 ----------------------
# Epoch 100/1, Loss: 0.045802321285009384
# Episode 116: Reward = -29.57, TR = -28.58, Loss = 0.045802321285009384
# Start episode 117 ----------------------
# Epoch 100/1, Loss: 0.040880780667066574
# Episode 117: Reward = -28.52, TR = -28.52, Loss = 0.040880780667066574
# Start episode 118 ----------------------
# Epoch 100/1, Loss: 0.02574058622121811
# Episode 118: Reward = -28.12, TR = -28.12, Loss = 0.02574058622121811
# Start episode 119 ----------------------
# Epoch 100/1, Loss: 0.03269026055932045
# Episode 119: Reward = -28.78, TR = -28.12, Loss = 0.03269026055932045
